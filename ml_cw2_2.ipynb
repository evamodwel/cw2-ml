# %% [markdown]
# # Environment Setup

# %% [markdown]
# Download needed Libraries

# %%
# !pip install torch torchvision scikit-learn numpy matplotlib
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.10.0+cpu)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cpu)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch) (2025.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)

# %% [markdown]
# Import the libraries

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import torchvision.models as models
import numpy as np
import os
from google.colab import drive
print("GPU is available:", torch.cuda.is_available())
# Out:
# GPU is available: True

# %% [markdown]
# Connect to Drive
#
# *necessary to save embeddings while the model trains*

# %%
drive.mount('/content/drive')
SAVE_PATH = '/content/drive/MyDrive/simclr_model_cw2.pth'
EMBEDDINGS_PATH = '/content/drive/MyDrive/embeddings_cw2.npy'
LABELS_PATH = '/content/drive/MyDrive/labels_cw2.npy'
print("Drive mounted successfully")
# Out:
# Mounted at /content/drive
# Drive mounted successfully

# %% [markdown]
# # Embeddings

# %% [markdown]
# SimCLR Augmentation and Dataset

# %%
# does the simclr augmentations as described in the paper
def get_augmented_data():
    return transforms.Compose([
        transforms.RandomResizedCrop(32),
        transforms.RandomHorizontalFlip(),
        transforms.ColorJitter(0.4, 0.4, 0.4, 0.1),
        transforms.RandomGrayscale(p=0.2), #20% chance of being grayscale
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2023, 0.1994, 0.2010)
        )
    ])

# dataset class that returns 2 views of each image
class SimCLRDataset(torch.utils.data.Dataset):
    def __init__(self, transform):
        # downloads the CIFAR images
        self.dataset = torchvision.datasets.CIFAR10(root='./data',train=True,download=True,transform=None)
        self.transform = transform

    def __len__(self):
        return len(self.dataset) # 50,000 images in the dataset

    def __getitem__(self, idx):
        image, label = self.dataset[idx]
        view1 = self.transform(image)
        view2 = self.transform(image)
        # view1 and view2 different cause augmentation is randomized
        return view1, view2

simclr_dataset = SimCLRDataset(get_augmented_data()) # doesn't actually do any data processing yet - just configuration
# batch size as provided in research paper
simclr_loader = DataLoader(simclr_dataset,batch_size=512,shuffle=True,drop_last=True)

print(f"Size of dataset: {len(simclr_dataset)}")
print(f"Number of batches: {len(simclr_loader)}")
# Out:
# 100%|██████████| 170M/170M [00:13<00:00, 12.5MB/s]
# Size of dataset: 50000
# Number of batches: 97

# %% [markdown]
# SimCLR Model Creation
#
# *tested with dummy images to verify before actual training*

# %%
#just builds the structure of the model
class SimCLR(nn.Module):
    def __init__(self):
        super().__init__()
        resnet = models.resnet18(weights=None) # without any pre-trained weights
        # resnet.children() returns the layers like convolutional layers, relu, etc.
        # last layer removed because we want the output of the second last layer - 512 dimensional output
        self.backbone = nn.Sequential(*list(resnet.children())[:-1])
        # gets the 512 dim down to 128 as per the paper
        self.projection = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),
            nn.Linear(512, 128)
        )

    def forward(self, x):
        h = self.backbone(x)
        h = h.view(h.size(0), -1) # flattens the previous output
        z = self.projection(h) # 128 dimensional output
        return h, z

# testing with a dummy to avoid future errors before the actual training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"CPU or GPU being used: {device}")
test_model = SimCLR().to(device)
dummy = torch.randn(2, 3, 32, 32).to(device)
h, z = test_model(dummy)
print(f"Intermediate flattened shape (h): {h.shape}")   # should be (2, 512)
print(f"Final shape (z): {z.shape}") # should be (2, 128)

#free's gpu space
del test_model, dummy
# Out:
# CPU or GPU being used: cuda
# Intermediate flattened shape (h): torch.Size([2, 512])
# Final shape (z): torch.Size([2, 128])

# %% [markdown]
# Contrastive Loss Function
#
# *compares similar and disimilar pairs*

# %%
def contrastive_loss(z1, z2, temperature=0.5): # 2 views as embeddings and temperature given by paper
    batch_size = z1.shape[0]
    z1 = F.normalize(z1, dim=1) # l2 normalizing views to ensure only direction taken into consideration not magnitude
    z2 = F.normalize(z2, dim=1)
    z = torch.cat([z1, z2], dim=0) # matrix so each pair can be compared
    # torch.mm does matrix multiplication with its transpose
    # computes a similarity score between each possible embedding
    sim = torch.mm(z, z.T) / temperature
    labels = torch.arange(batch_size, device=z1.device)
    labels = torch.cat([labels + batch_size, labels])
    mask = torch.eye(2 * batch_size, device=z1.device).bool() # True false matrix created
    sim.masked_fill_(mask, float('-inf')) # to ensure model doesn't consider its own pair as most similar
    loss = F.cross_entropy(sim, labels) # cross entropy loss
    return loss

# testing above with fake inputs
z1_test = torch.randn(4, 128).to(device)
z2_test = torch.randn(4, 128).to(device)
test_loss = contrastive_loss(z1_test, z2_test)
print(f"Loss function verified. Test loss: {test_loss.item():.4f}")
# Out:
# Loss function verified. Test loss: 1.9781

# %% [markdown]
# Training the SimCLR model

# %%
EPOCHS = 50

# checks if model already exists
if os.path.exists(SAVE_PATH):
    print("model already saved - no training required")
    model = SimCLR().to(device)
    model.load_state_dict(torch.load(SAVE_PATH)) # loads the model
else:
    print("training model since none found in drive")
    model = SimCLR().to(device)
    # hyperparameters as mentioned in the paper
    optimizer = torch.optim.SGD(model.parameters(),lr=0.4,momentum=0.9,weight_decay=0.0001)
    # gradually reduceing learning rate from the paper
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer,T_max=EPOCHS)

    for epoch in range(EPOCHS): # runs number of times of the epoch
        model.train()
        total_loss = 0
        for view1, view2 in simclr_loader: # runs through each image batch (of 512 images each)
            view1, view2 = view1.to(device), view2.to(device)
            _, z1 = model(view1) # only final view required
            _, z2 = model(view2) # not the intermediate flattened one
            loss = contrastive_loss(z1, z2)
            # standard training process
            optimizer.zero_grad() # gradient removed
            loss.backward() # new ones computed
            optimizer.step() # weights updated
            total_loss += loss.item()
        scheduler.step() # lr updated
        avg_loss = total_loss / len(simclr_loader) # loss should be reducing
        print(f"epoch {epoch+1}/{EPOCHS} - loss: {avg_loss:.4f}")

        # saves every 10 epochs
        if (epoch + 1) % 10 == 0:
            torch.save(model.state_dict(), SAVE_PATH)
            print(f"checkpoint save at epoch {epoch+1}")

    print("training done")
    torch.save(model.state_dict(), SAVE_PATH)
    print("model saved to drive")
# Out:
# training model since none found in drive
# epoch 1/50 - loss: 6.3361
# epoch 2/50 - loss: 6.1285
# epoch 3/50 - loss: 6.0604
# epoch 4/50 - loss: 6.0165
# epoch 5/50 - loss: 5.9732
# epoch 6/50 - loss: 5.9426
# epoch 7/50 - loss: 5.9256
# epoch 8/50 - loss: 5.8927
# epoch 9/50 - loss: 5.8627
# epoch 10/50 - loss: 5.8426
# checkpoint save at epoch 10
# epoch 11/50 - loss: 5.8368
# epoch 12/50 - loss: 5.8212
# epoch 13/50 - loss: 5.8089
# epoch 14/50 - loss: 5.7913
# epoch 15/50 - loss: 5.7790
# epoch 16/50 - loss: 5.7699
# epoch 17/50 - loss: 5.7614
# epoch 18/50 - loss: 5.7505
# epoch 19/50 - loss: 5.7478
# epoch 20/50 - loss: 5.7421
# checkpoint save at epoch 20
# epoch 21/50 - loss: 5.7334
# epoch 22/50 - loss: 5.7291
# epoch 23/50 - loss: 5.7166
# epoch 24/50 - loss: 5.7111
# epoch 25/50 - loss: 5.7066
# epoch 26/50 - loss: 5.7057
# epoch 27/50 - loss: 5.6972
# epoch 28/50 - loss: 5.6916
# epoch 29/50 - loss: 5.6874
# epoch 30/50 - loss: 5.6790
# checkpoint save at epoch 30
# epoch 31/50 - loss: 5.6782
# epoch 32/50 - loss: 5.6684
# epoch 33/50 - loss: 5.6632
# epoch 34/50 - loss: 5.6565
# epoch 35/50 - loss: 5.6518
# epoch 36/50 - loss: 5.6466
# epoch 37/50 - loss: 5.6422
# epoch 38/50 - loss: 5.6384
# epoch 39/50 - loss: 5.6336
# epoch 40/50 - loss: 5.6322
# checkpoint save at epoch 40
# epoch 41/50 - loss: 5.6307
# epoch 42/50 - loss: 5.6318
# epoch 43/50 - loss: 5.6215
# epoch 44/50 - loss: 5.6188
# epoch 45/50 - loss: 5.6183
# epoch 46/50 - loss: 5.6134
# epoch 47/50 - loss: 5.6085
# epoch 48/50 - loss: 5.6111
# epoch 49/50 - loss: 5.6102
# epoch 50/50 - loss: 5.6129
# checkpoint save at epoch 50
# training done
# model saved to drive

# %% [markdown]
# Load Model

# %%
model = SimCLR().to(device)
model.load_state_dict(torch.load(SAVE_PATH, map_location=device))
model.eval()
print("model loaded")
# Out:
# model loaded

# %% [markdown]
# Extract Saved Embeddings

# %%
# function that actually embeds using the model we trained earlier
def extract_save_embeddings(model, device):
  if os.path.exists(EMBEDDINGS_PATH): # skips everything if embedding already exists
    print("embeddings being downloaded from drive")
    embeddings = np.load(EMBEDDINGS_PATH)
    labels = np.load(LABELS_PATH)
    print(embeddings.shape)
    return embeddings, labels

  # no augmentations
  extract_transform = transforms.Compose([
      transforms.ToTensor(),
      transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2023, 0.1994, 0.2010)
        )
  ])

  # loads data using above transformation
  extract_dataset = torchvision.datasets.CIFAR10(root='./data',train=True,download=True,transform=extract_transform)
  extract_dataloader = DataLoader(extract_dataset,batch_size=256,shuffle=False) # shouldn't shuffle so embeddings stay intact

  model.eval() # eval mode - for consistent embeddings
  embeddings = []
  labels = []

  with torch.no_grad():
    for images, target in extract_dataloader:
      images = images.to(device)
      h, _ = model(images) # don't need final - we need the 512 dimensional output
      h = F.normalize(h, dim=1) # L2 normalizing each embedding - only directional
      embeddings.append(h.cpu().numpy())
      labels.append(target.numpy())

  embeddings = np.concatenate(embeddings, axis=0) # combines to a single array/matrix
  labels = np.concatenate(labels, axis=0)

  np.save(EMBEDDINGS_PATH, embeddings)
  np.save(LABELS_PATH, labels)
  print("embeddings saved")

  return embeddings, labels

embeddings, labels = extract_save_embeddings(model, device)
# Out:
# embeddings being downloaded from drive
# (50000, 512)

# %% [markdown]
# # Clustering

# %% [markdown]
# Imports

# %%
from sklearn.cluster import KMeans, MiniBatchKMeans
import numpy as np

# %% [markdown]
# KMeans

# %%
def cluster_embeddings(budget):
  K = min(budget, 500)
  if K <= 50:
    clusters = KMeans(n_clusters=K, random_state=42).fit_predict(embeddings)
  else:
    clusters = MiniBatchKMeans(n_clusters=K, random_state=42).fit_predict(embeddings)

  unique, counts = np.unique(clusters, return_counts=True)

  # print("budget: ", budget)
  # print("clusters: ", K)
  # print("number of points in each cluster: ", counts)
  # print(unique)

  return K, clusters

# cluster_embeddings(10)

# %% [markdown]
# # Typicality

# %% [markdown]
# Imports

# %%
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# Method for Highest Typicality

# %%
def get_highest_typicality(K, clusters, k):
  selected_indices = []
  for clustid in range(K): # goes through all 10 clusters one by one
    # print("ID",clustid)
    cluster_idx = np.where(clusters == clustid)[0] # checks if each point is in that cluster
    if len(cluster_idx) < 5:
      continue

    embeddings_for_cluster = embeddings[cluster_idx] # embedding of this cluster

    k_neighbours = min(k, len(cluster_idx)) # only distance to k embeddings - we don't calculate typicality for all
    neighbours = NearestNeighbors(n_neighbors=k_neighbours).fit(embeddings_for_cluster)
    nbdist,_ = neighbours.kneighbors(embeddings_for_cluster)

    avg_dist = nbdist[:, 1:].mean(axis=1)
    typicality = 1 / (avg_dist + 1e-8) # avoids division by 0

    highest_typicality_local = np.argmax(typicality)
    highest_typicality_global = cluster_idx[highest_typicality_local]

    selected_indices.append(highest_typicality_global)

  selected_indices = np.array(selected_indices)
  # print("selected indices: ", selected_indices)
  return selected_indices

# K, clusters = cluster_embeddings(10)
# selected_indices = get_highest_typicality(K,clusters)

# %% [markdown]
# # Training the Classifier

# %% [markdown]
# Imports

# %%
from torch.utils.data import Subset

# %% [markdown]
# Training Loop

# %%
def train_classifier(selected_indices, lr):
  full_data = torchvision.datasets.CIFAR10(
    root='./data',
    train=True,
    download=True,
    transform=transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(
            (0.4914, 0.4822, 0.4465),
            (0.2023, 0.1994, 0.2010)
        )
    ])
)

  classifier = nn.Linear(512, 10).to(device) # 512 inputs and 10 outputs

  model.eval() # no weight updating
  for param in model.parameters():
    param.requires_grad = False # frozen

  # parameters from the paper
  optimizer = torch.optim.SGD(classifier.parameters(), lr=lr, momentum=0.9)
  criterion = nn.CrossEntropyLoss()

  labeled_subset = Subset(full_data, selected_indices)
  labeled_loader = DataLoader(labeled_subset, batch_size=len(selected_indices), shuffle=True)
  # print("labeled points: ", len(labeled_subset))

  CLASSIFIER_EPOCHS = 100

  for epoch in range(CLASSIFIER_EPOCHS):
    classifier.train()
    total_loss = 0
    for images, labels in labeled_loader:
      images, labels = images.to(device), labels.to(device)

      with torch.no_grad():
        h, _ = model(images)
        h = F.normalize(h, dim=1)

      outputs = classifier(h)
      loss = criterion(outputs, labels)
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      total_loss += loss.item()

    if (epoch + 1) % 10 == 0:
      print(f"epoch {epoch+1}/{CLASSIFIER_EPOCHS} - loss: {total_loss/len(labeled_loader):.4f}")

  print("classifier training done")
  return classifier

# train_classifier()

# %% [markdown]
# # Evaluation

# %% [markdown]
# Load Test Data

# %%
test_transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(
        (0.4914, 0.4822, 0.4465),
        (0.2023, 0.1994, 0.2010)
    )
])

test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=test_transform)
test_loader = DataLoader(test_dataset, batch_size=256, shuffle=False)
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 43.3MB/s]

# %% [markdown]
# Evaluation Function

# %%
def evaluate_classifier(classifier):
  correct = 0
  total = 0

  model.eval()
  classifier.eval()

  for test_images, test_labels in test_loader:
    test_images, test_labels = test_images.to(device), test_labels.to(device)
    with torch.no_grad():
      h, _ = model(test_images)
      h = F.normalize(h, dim=1)

    outputs = classifier(h)
    _, predicted = outputs.max(1) # class with highest score

    correct += predicted.eq(test_labels).sum().item()
    total += test_labels.size(0)

  accuracy = 100 * correct / total
  print(f"test accuracy: {accuracy:.2f}%")
  return accuracy

# evaluate_classifier()

# %% [markdown]
# # Optimization

# %% [markdown]
# Finding Optimal k-value for typicality

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
k_values = [20, 30, 40, 50, 60, 70]
results = {}

for B in budgets:
  for k in k_values:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality(B, cluster, k)
    classifier = train_classifier(selected_indices, 0.025)
    accuracy = evaluate_classifier(classifier)
    results[(B, k)] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for (B, k), acc in results.items():
    print(f"B={B}, k={k}: {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 2.1960
# epoch 20/100 - loss: 1.9932
# epoch 30/100 - loss: 1.7972
# epoch 40/100 - loss: 1.6274
# epoch 50/100 - loss: 1.4793
# epoch 60/100 - loss: 1.3474
# epoch 70/100 - loss: 1.2291
# epoch 80/100 - loss: 1.1232
# epoch 90/100 - loss: 1.0284
# epoch 100/100 - loss: 0.9438
# classifier training done
# test accuracy: 33.29%
# Budget 10 - Accuracy: 33.29%
# epoch 10/100 - loss: 2.1917
# epoch 20/100 - loss: 1.9907
# epoch 30/100 - loss: 1.7951
# epoch 40/100 - loss: 1.6247
# epoch 50/100 - loss: 1.4755
# epoch 60/100 - loss: 1.3426
# epoch 70/100 - loss: 1.2236
# epoch 80/100 - loss: 1.1169
# epoch 90/100 - loss: 1.0217
# epoch 100/100 - loss: 0.9366
# classifier training done
# test accuracy: 34.09%
# Budget 10 - Accuracy: 34.09%
# epoch 10/100 - loss: 2.1947
# epoch 20/100 - loss: 1.9949
# epoch 30/100 - loss: 1.8000
# epoch 40/100 - loss: 1.6298
# epoch 50/100 - loss: 1.4805
# epoch 60/100 - loss: 1.3474
# epoch 70/100 - loss: 1.2281
# epoch 80/100 - loss: 1.1212
# epoch 90/100 - loss: 1.0257
# epoch 100/100 - loss: 0.9404
# classifier training done
# test accuracy: 33.94%
# Budget 10 - Accuracy: 33.94%
# epoch 10/100 - loss: 2.2058
# epoch 20/100 - loss: 2.0017
# epoch 30/100 - loss: 1.8039
# epoch 40/100 - loss: 1.6325
# epoch 50/100 - loss: 1.4830
# epoch 60/100 - loss: 1.3499
# epoch 70/100 - loss: 1.2308
# epoch 80/100 - loss: 1.1240
# epoch 90/100 - loss: 1.0286
# epoch 100/100 - loss: 0.9434
# classifier training done
# test accuracy: 33.89%
# Budget 10 - Accuracy: 33.89%
# epoch 10/100 - loss: 2.2003
# epoch 20/100 - loss: 2.0000
# epoch 30/100 - loss: 1.8052
# epoch 40/100 - loss: 1.6359
# epoch 50/100 - loss: 1.4878
# epoch 60/100 - loss: 1.3557
# epoch 70/100 - loss: 1.2371
# epoch 80/100 - loss: 1.1306
# epoch 90/100 - loss: 1.0353
# epoch 100/100 - loss: 0.9500
# classifier training done
# test accuracy: 33.73%
# Budget 10 - Accuracy: 33.73%
# epoch 10/100 - loss: 2.1882
# epoch 20/100 - loss: 1.9922
# epoch 30/100 - loss: 1.8003
# epoch 40/100 - loss: 1.6320
# epoch 50/100 - loss: 1.4840
# epoch 60/100 - loss: 1.3519
# epoch 70/100 - loss: 1.2334
# epoch 80/100 - loss: 1.1272
# epoch 90/100 - loss: 1.0321
# epoch 100/100 - loss: 0.9470
# classifier training done
# test accuracy: 33.60%
# Budget 10 - Accuracy: 33.60%
# epoch 10/100 - loss: 2.2576
# epoch 20/100 - loss: 2.1745
# epoch 30/100 - loss: 2.0875
# epoch 40/100 - loss: 2.0061
# epoch 50/100 - loss: 1.9309
# epoch 60/100 - loss: 1.8610
# epoch 70/100 - loss: 1.7957
# epoch 80/100 - loss: 1.7344
# epoch 90/100 - loss: 1.6768
# epoch 100/100 - loss: 1.6226
# classifier training done
# test accuracy: 33.50%
# Budget 50 - Accuracy: 33.50%
# epoch 10/100 - loss: 2.2662
# epoch 20/100 - loss: 2.1777
# epoch 30/100 - loss: 2.0856
# epoch 40/100 - loss: 1.9999
# epoch 50/100 - loss: 1.9208
# epoch 60/100 - loss: 1.8473
# epoch 70/100 - loss: 1.7783
# epoch 80/100 - loss: 1.7135
# epoch 90/100 - loss: 1.6526
# epoch 100/100 - loss: 1.5952
# classifier training done
# test accuracy: 34.63%
# Budget 50 - Accuracy: 34.63%
# epoch 10/100 - loss: 2.2593
# epoch 20/100 - loss: 2.1671
# epoch 30/100 - loss: 2.0731
# epoch 40/100 - loss: 1.9875
# epoch 50/100 - loss: 1.9094
# epoch 60/100 - loss: 1.8371
# epoch 70/100 - loss: 1.7696
# epoch 80/100 - loss: 1.7063
# epoch 90/100 - loss: 1.6470
# epoch 100/100 - loss: 1.5913
# classifier training done
# test accuracy: 33.18%
# Budget 50 - Accuracy: 33.18%
# epoch 10/100 - loss: 2.2355
# epoch 20/100 - loss: 2.1370
# epoch 30/100 - loss: 2.0384
# epoch 40/100 - loss: 1.9502
# epoch 50/100 - loss: 1.8711
# epoch 60/100 - loss: 1.7987
# epoch 70/100 - loss: 1.7317
# epoch 80/100 - loss: 1.6693
# epoch 90/100 - loss: 1.6110
# epoch 100/100 - loss: 1.5564
# classifier training done
# test accuracy: 32.82%
# Budget 50 - Accuracy: 32.82%
# epoch 10/100 - loss: 2.2551
# epoch 20/100 - loss: 2.1668
# epoch 30/100 - loss: 2.0739
# epoch 40/100 - loss: 1.9866
# epoch 50/100 - loss: 1.9059
# epoch 60/100 - loss: 1.8309
# epoch 70/100 - loss: 1.7608
# epoch 80/100 - loss: 1.6951
# epoch 90/100 - loss: 1.6334
# epoch 100/100 - loss: 1.5755
# classifier training done
# test accuracy: 37.54%
# Budget 50 - Accuracy: 37.54%
# epoch 10/100 - loss: 2.2682
# epoch 20/100 - loss: 2.1772
# epoch 30/100 - loss: 2.0823
# epoch 40/100 - loss: 1.9938
# epoch 50/100 - loss: 1.9125
# epoch 60/100 - loss: 1.8372
# epoch 70/100 - loss: 1.7669
# epoch 80/100 - loss: 1.7012
# epoch 90/100 - loss: 1.6395
# epoch 100/100 - loss: 1.5816
# classifier training done
# test accuracy: 37.27%
# Budget 50 - Accuracy: 37.27%
# epoch 10/100 - loss: 2.2738
# epoch 20/100 - loss: 2.2161
# epoch 30/100 - loss: 2.1531
# epoch 40/100 - loss: 2.0917
# epoch 50/100 - loss: 2.0334
# epoch 60/100 - loss: 1.9781
# epoch 70/100 - loss: 1.9255
# epoch 80/100 - loss: 1.8756
# epoch 90/100 - loss: 1.8281
# epoch 100/100 - loss: 1.7831
# classifier training done
# test accuracy: 35.68%
# Budget 100 - Accuracy: 35.68%
# epoch 10/100 - loss: 2.2774
# epoch 20/100 - loss: 2.2243
# epoch 30/100 - loss: 2.1640
# epoch 40/100 - loss: 2.1036
# epoch 50/100 - loss: 2.0450
# epoch 60/100 - loss: 1.9890
# epoch 70/100 - loss: 1.9355
# epoch 80/100 - loss: 1.8846
# epoch 90/100 - loss: 1.8361
# epoch 100/100 - loss: 1.7899
# classifier training done
# test accuracy: 41.09%
# Budget 100 - Accuracy: 41.09%
# epoch 10/100 - loss: 2.2788
# epoch 20/100 - loss: 2.2241
# epoch 30/100 - loss: 2.1625
# epoch 40/100 - loss: 2.1012
# epoch 50/100 - loss: 2.0421
# epoch 60/100 - loss: 1.9856
# epoch 70/100 - loss: 1.9316
# epoch 80/100 - loss: 1.8803
# epoch 90/100 - loss: 1.8314
# epoch 100/100 - loss: 1.7849
# classifier training done
# test accuracy: 38.89%
# Budget 100 - Accuracy: 38.89%
# epoch 10/100 - loss: 2.2784
# epoch 20/100 - loss: 2.2251
# epoch 30/100 - loss: 2.1650
# epoch 40/100 - loss: 2.1053
# epoch 50/100 - loss: 2.0476
# epoch 60/100 - loss: 1.9926
# epoch 70/100 - loss: 1.9402
# epoch 80/100 - loss: 1.8903
# epoch 90/100 - loss: 1.8429
# epoch 100/100 - loss: 1.7978
# classifier training done
# test accuracy: 38.59%
# Budget 100 - Accuracy: 38.59%
# epoch 10/100 - loss: 2.2814
# epoch 20/100 - loss: 2.2306
# epoch 30/100 - loss: 2.1728
# epoch 40/100 - loss: 2.1146
# epoch 50/100 - loss: 2.0581
# epoch 60/100 - loss: 2.0040
# epoch 70/100 - loss: 1.9525
# epoch 80/100 - loss: 1.9034
# epoch 90/100 - loss: 1.8567
# epoch 100/100 - loss: 1.8123
# classifier training done
# test accuracy: 42.19%
# Budget 100 - Accuracy: 42.19%
# epoch 10/100 - loss: 2.2912
# epoch 20/100 - loss: 2.2386
# epoch 30/100 - loss: 2.1793
# epoch 40/100 - loss: 2.1200
# epoch 50/100 - loss: 2.0629
# epoch 60/100 - loss: 2.0082
# epoch 70/100 - loss: 1.9562
# epoch 80/100 - loss: 1.9067
# epoch 90/100 - loss: 1.8597
# epoch 100/100 - loss: 1.8150
# classifier training done
# test accuracy: 42.46%
# Budget 100 - Accuracy: 42.46%
# epoch 10/100 - loss: 2.2792
# epoch 20/100 - loss: 2.2339
# epoch 30/100 - loss: 2.1842
# epoch 40/100 - loss: 2.1355
# epoch 50/100 - loss: 2.0890
# epoch 60/100 - loss: 2.0445
# epoch 70/100 - loss: 2.0020
# epoch 80/100 - loss: 1.9614
# epoch 90/100 - loss: 1.9226
# epoch 100/100 - loss: 1.8856
# classifier training done
# test accuracy: 38.01%
# Budget 200 - Accuracy: 38.01%
# epoch 10/100 - loss: 2.2835
# epoch 20/100 - loss: 2.2382
# epoch 30/100 - loss: 2.1886
# epoch 40/100 - loss: 2.1402
# epoch 50/100 - loss: 2.0940
# epoch 60/100 - loss: 2.0500
# epoch 70/100 - loss: 2.0080
# epoch 80/100 - loss: 1.9679
# epoch 90/100 - loss: 1.9296
# epoch 100/100 - loss: 1.8931
# classifier training done
# test accuracy: 37.14%
# Budget 200 - Accuracy: 37.14%
# epoch 10/100 - loss: 2.2808
# epoch 20/100 - loss: 2.2349
# epoch 30/100 - loss: 2.1851
# epoch 40/100 - loss: 2.1369
# epoch 50/100 - loss: 2.0910
# epoch 60/100 - loss: 2.0474
# epoch 70/100 - loss: 2.0059
# epoch 80/100 - loss: 1.9662
# epoch 90/100 - loss: 1.9283
# epoch 100/100 - loss: 1.8921
# classifier training done
# test accuracy: 35.63%
# Budget 200 - Accuracy: 35.63%
# epoch 10/100 - loss: 2.2861
# epoch 20/100 - loss: 2.2411
# epoch 30/100 - loss: 2.1918
# epoch 40/100 - loss: 2.1437
# epoch 50/100 - loss: 2.0976
# epoch 60/100 - loss: 2.0537
# epoch 70/100 - loss: 2.0117
# epoch 80/100 - loss: 1.9716
# epoch 90/100 - loss: 1.9332
# epoch 100/100 - loss: 1.8966
# classifier training done
# test accuracy: 38.35%
# Budget 200 - Accuracy: 38.35%
# epoch 10/100 - loss: 2.2810
# epoch 20/100 - loss: 2.2342
# epoch 30/100 - loss: 2.1831
# epoch 40/100 - loss: 2.1332
# epoch 50/100 - loss: 2.0857
# epoch 60/100 - loss: 2.0404
# epoch 70/100 - loss: 1.9972
# epoch 80/100 - loss: 1.9560
# epoch 90/100 - loss: 1.9166
# epoch 100/100 - loss: 1.8790
# classifier training done
# test accuracy: 42.59%
# Budget 200 - Accuracy: 42.59%
# epoch 10/100 - loss: 2.2868
# epoch 20/100 - loss: 2.2408
# epoch 30/100 - loss: 2.1906
# epoch 40/100 - loss: 2.1417
# epoch 50/100 - loss: 2.0950
# epoch 60/100 - loss: 2.0504
# epoch 70/100 - loss: 2.0077
# epoch 80/100 - loss: 1.9669
# epoch 90/100 - loss: 1.9279
# epoch 100/100 - loss: 1.8906
# classifier training done
# test accuracy: 37.00%
# Budget 200 - Accuracy: 37.00%
# epoch 10/100 - loss: 2.2792
# epoch 20/100 - loss: 2.2360
# epoch 30/100 - loss: 2.1888
# epoch 40/100 - loss: 2.1426
# epoch 50/100 - loss: 2.0986
# epoch 60/100 - loss: 2.0565
# epoch 70/100 - loss: 2.0164
# epoch 80/100 - loss: 1.9781
# epoch 90/100 - loss: 1.9415
# epoch 100/100 - loss: 1.9066
# classifier training done
# test accuracy: 39.12%
# Budget 300 - Accuracy: 39.12%
# epoch 10/100 - loss: 2.2806
# epoch 20/100 - loss: 2.2361
# epoch 30/100 - loss: 2.1886
# epoch 40/100 - loss: 2.1432
# epoch 50/100 - loss: 2.1004
# epoch 60/100 - loss: 2.0597
# epoch 70/100 - loss: 2.0209
# epoch 80/100 - loss: 1.9840
# epoch 90/100 - loss: 1.9487
# epoch 100/100 - loss: 1.9149
# classifier training done
# test accuracy: 40.81%
# Budget 300 - Accuracy: 40.81%
# epoch 10/100 - loss: 2.2825
# epoch 20/100 - loss: 2.2400
# epoch 30/100 - loss: 2.1939
# epoch 40/100 - loss: 2.1492
# epoch 50/100 - loss: 2.1067
# epoch 60/100 - loss: 2.0663
# epoch 70/100 - loss: 2.0277
# epoch 80/100 - loss: 1.9909
# epoch 90/100 - loss: 1.9557
# epoch 100/100 - loss: 1.9221
# classifier training done
# test accuracy: 40.22%
# Budget 300 - Accuracy: 40.22%
# epoch 10/100 - loss: 2.2884
# epoch 20/100 - loss: 2.2451
# epoch 30/100 - loss: 2.1988
# epoch 40/100 - loss: 2.1544
# epoch 50/100 - loss: 2.1124
# epoch 60/100 - loss: 2.0725
# epoch 70/100 - loss: 2.0344
# epoch 80/100 - loss: 1.9981
# epoch 90/100 - loss: 1.9633
# epoch 100/100 - loss: 1.9301
# classifier training done
# test accuracy: 39.07%
# Budget 300 - Accuracy: 39.07%
# epoch 10/100 - loss: 2.2878
# epoch 20/100 - loss: 2.2441
# epoch 30/100 - loss: 2.1975
# epoch 40/100 - loss: 2.1531
# epoch 50/100 - loss: 2.1112
# epoch 60/100 - loss: 2.0714
# epoch 70/100 - loss: 2.0335
# epoch 80/100 - loss: 1.9972
# epoch 90/100 - loss: 1.9625
# epoch 100/100 - loss: 1.9294
# classifier training done
# test accuracy: 38.72%
# Budget 300 - Accuracy: 38.72%
# epoch 10/100 - loss: 2.2823
# epoch 20/100 - loss: 2.2408
# epoch 30/100 - loss: 2.1962
# epoch 40/100 - loss: 2.1535
# epoch 50/100 - loss: 2.1130
# epoch 60/100 - loss: 2.0744
# epoch 70/100 - loss: 2.0375
# epoch 80/100 - loss: 2.0022
# epoch 90/100 - loss: 1.9685
# epoch 100/100 - loss: 1.9363
# classifier training done
# test accuracy: 36.22%
# Budget 300 - Accuracy: 36.22%
# epoch 10/100 - loss: 2.2801
# epoch 20/100 - loss: 2.2414
# epoch 30/100 - loss: 2.1991
# epoch 40/100 - loss: 2.1578
# epoch 50/100 - loss: 2.1184
# epoch 60/100 - loss: 2.0809
# epoch 70/100 - loss: 2.0451
# epoch 80/100 - loss: 2.0111
# epoch 90/100 - loss: 1.9785
# epoch 100/100 - loss: 1.9475
# classifier training done
# test accuracy: 39.93%
# Budget 400 - Accuracy: 39.93%
# epoch 10/100 - loss: 2.2868
# epoch 20/100 - loss: 2.2517
# epoch 30/100 - loss: 2.2120
# epoch 40/100 - loss: 2.1723
# epoch 50/100 - loss: 2.1338
# epoch 60/100 - loss: 2.0969
# epoch 70/100 - loss: 2.0616
# epoch 80/100 - loss: 2.0278
# epoch 90/100 - loss: 1.9955
# epoch 100/100 - loss: 1.9646
# classifier training done
# test accuracy: 41.29%
# Budget 400 - Accuracy: 41.29%
# epoch 10/100 - loss: 2.2862
# epoch 20/100 - loss: 2.2471
# epoch 30/100 - loss: 2.2042
# epoch 40/100 - loss: 2.1622
# epoch 50/100 - loss: 2.1221
# epoch 60/100 - loss: 2.0839
# epoch 70/100 - loss: 2.0473
# epoch 80/100 - loss: 2.0125
# epoch 90/100 - loss: 1.9791
# epoch 100/100 - loss: 1.9473
# classifier training done
# test accuracy: 37.78%
# Budget 400 - Accuracy: 37.78%
# epoch 10/100 - loss: 2.2866
# epoch 20/100 - loss: 2.2472
# epoch 30/100 - loss: 2.2040
# epoch 40/100 - loss: 2.1618
# epoch 50/100 - loss: 2.1214
# epoch 60/100 - loss: 2.0828
# epoch 70/100 - loss: 2.0459
# epoch 80/100 - loss: 2.0106
# epoch 90/100 - loss: 1.9769
# epoch 100/100 - loss: 1.9446
# classifier training done
# test accuracy: 38.69%
# Budget 400 - Accuracy: 38.69%
# epoch 10/100 - loss: 2.2863
# epoch 20/100 - loss: 2.2488
# epoch 30/100 - loss: 2.2069
# epoch 40/100 - loss: 2.1654
# epoch 50/100 - loss: 2.1254
# epoch 60/100 - loss: 2.0871
# epoch 70/100 - loss: 2.0505
# epoch 80/100 - loss: 2.0154
# epoch 90/100 - loss: 1.9818
# epoch 100/100 - loss: 1.9496
# classifier training done
# test accuracy: 42.12%
# Budget 400 - Accuracy: 42.12%
# epoch 10/100 - loss: 2.2800
# epoch 20/100 - loss: 2.2424
# epoch 30/100 - loss: 2.2009
# epoch 40/100 - loss: 2.1601
# epoch 50/100 - loss: 2.1211
# epoch 60/100 - loss: 2.0838
# epoch 70/100 - loss: 2.0481
# epoch 80/100 - loss: 2.0140
# epoch 90/100 - loss: 1.9814
# epoch 100/100 - loss: 1.9501
# classifier training done
# test accuracy: 41.02%
# Budget 400 - Accuracy: 41.02%
# epoch 10/100 - loss: 2.2867
# epoch 20/100 - loss: 2.2517
# epoch 30/100 - loss: 2.2125
# epoch 40/100 - loss: 2.1734
# epoch 50/100 - loss: 2.1356
# epoch 60/100 - loss: 2.0993
# epoch 70/100 - loss: 2.0645
# epoch 80/100 - loss: 2.0312
# epoch 90/100 - loss: 1.9992
# epoch 100/100 - loss: 1.9686
# classifier training done
# test accuracy: 44.72%
# Budget 500 - Accuracy: 44.72%
# epoch 10/100 - loss: 2.2951
# epoch 20/100 - loss: 2.2609
# epoch 30/100 - loss: 2.2224
# epoch 40/100 - loss: 2.1841
# epoch 50/100 - loss: 2.1470
# epoch 60/100 - loss: 2.1114
# epoch 70/100 - loss: 2.0772
# epoch 80/100 - loss: 2.0445
# epoch 90/100 - loss: 2.0132
# epoch 100/100 - loss: 1.9832
# classifier training done
# test accuracy: 42.55%
# Budget 500 - Accuracy: 42.55%
# epoch 10/100 - loss: 2.2833
# epoch 20/100 - loss: 2.2498
# epoch 30/100 - loss: 2.2120
# epoch 40/100 - loss: 2.1743
# epoch 50/100 - loss: 2.1378
# epoch 60/100 - loss: 2.1027
# epoch 70/100 - loss: 2.0691
# epoch 80/100 - loss: 2.0369
# epoch 90/100 - loss: 2.0060
# epoch 100/100 - loss: 1.9765
# classifier training done
# test accuracy: 44.82%
# Budget 500 - Accuracy: 44.82%
# epoch 10/100 - loss: 2.2920
# epoch 20/100 - loss: 2.2586
# epoch 30/100 - loss: 2.2210
# epoch 40/100 - loss: 2.1837
# epoch 50/100 - loss: 2.1477
# epoch 60/100 - loss: 2.1131
# epoch 70/100 - loss: 2.0799
# epoch 80/100 - loss: 2.0481
# epoch 90/100 - loss: 2.0176
# epoch 100/100 - loss: 1.9884
# classifier training done
# test accuracy: 42.00%
# Budget 500 - Accuracy: 42.00%
# epoch 10/100 - loss: 2.2885
# epoch 20/100 - loss: 2.2548
# epoch 30/100 - loss: 2.2173
# epoch 40/100 - loss: 2.1801
# epoch 50/100 - loss: 2.1442
# epoch 60/100 - loss: 2.1098
# epoch 70/100 - loss: 2.0767
# epoch 80/100 - loss: 2.0451
# epoch 90/100 - loss: 2.0148
# epoch 100/100 - loss: 1.9857
# classifier training done
# test accuracy: 43.68%
# Budget 500 - Accuracy: 43.68%
# epoch 10/100 - loss: 2.2873
# epoch 20/100 - loss: 2.2539
# epoch 30/100 - loss: 2.2168
# epoch 40/100 - loss: 2.1801
# epoch 50/100 - loss: 2.1447
# epoch 60/100 - loss: 2.1108
# epoch 70/100 - loss: 2.0783
# epoch 80/100 - loss: 2.0471
# epoch 90/100 - loss: 2.0172
# epoch 100/100 - loss: 1.9886
# classifier training done
# test accuracy: 42.55%
# Budget 500 - Accuracy: 42.55%
#
# Final Results:
# B=10, k=20: 33.29%
# B=10, k=30: 34.09%
# B=10, k=40: 33.94%
# B=10, k=50: 33.89%
# B=10, k=60: 33.73%
# B=10, k=70: 33.60%
# B=50, k=20: 33.50%
# B=50, k=30: 34.63%
# B=50, k=40: 33.18%
# B=50, k=50: 32.82%
# B=50, k=60: 37.54%
# B=50, k=70: 37.27%
# B=100, k=20: 35.68%
# B=100, k=30: 41.09%
# B=100, k=40: 38.89%
# B=100, k=50: 38.59%
# B=100, k=60: 42.19%
# B=100, k=70: 42.46%
# B=200, k=20: 38.01%
# B=200, k=30: 37.14%
# B=200, k=40: 35.63%
# B=200, k=50: 38.35%
# B=200, k=60: 42.59%
# B=200, k=70: 37.00%
# B=300, k=20: 39.12%
# B=300, k=30: 40.81%
# B=300, k=40: 40.22%
# B=300, k=50: 39.07%
# B=300, k=60: 38.72%
# B=300, k=70: 36.22%
# B=400, k=20: 39.93%
# B=400, k=30: 41.29%
# B=400, k=40: 37.78%
# B=400, k=50: 38.69%
# B=400, k=60: 42.12%
# B=400, k=70: 41.02%
# B=500, k=20: 44.72%
# B=500, k=30: 42.55%
# B=500, k=40: 44.82%
# B=500, k=50: 42.00%
# B=500, k=60: 43.68%
# B=500, k=70: 42.55%

# %% [markdown]
# Finding Optimal LR for the classifier

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
best_k = 60
lr_values = [0.025, 0.01, 0.005, 0.05, 0.1, 0.5]
results = {}

for B in budgets:
  for lr in lr_values:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality(B, cluster, best_k)
    classifier = train_classifier(selected_indices, lr)
    accuracy = evaluate_classifier(classifier)
    results[(B, lr)] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for (B, lr), acc in results.items():
    print(f"B={B}, lr={lr}: {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 2.2031
# epoch 20/100 - loss: 2.0013
# epoch 30/100 - loss: 1.8056
# epoch 40/100 - loss: 1.6356
# epoch 50/100 - loss: 1.4870
# epoch 60/100 - loss: 1.3546
# epoch 70/100 - loss: 1.2359
# epoch 80/100 - loss: 1.1294
# epoch 90/100 - loss: 1.0341
# epoch 100/100 - loss: 0.9489
# classifier training done
# test accuracy: 33.85%
# Budget 10 - Accuracy: 33.85%
# epoch 10/100 - loss: 2.2617
# epoch 20/100 - loss: 2.1722
# epoch 30/100 - loss: 2.0747
# epoch 40/100 - loss: 1.9818
# epoch 50/100 - loss: 1.8963
# epoch 60/100 - loss: 1.8178
# epoch 70/100 - loss: 1.7453
# epoch 80/100 - loss: 1.6778
# epoch 90/100 - loss: 1.6143
# epoch 100/100 - loss: 1.5544
# classifier training done
# test accuracy: 21.32%
# Budget 10 - Accuracy: 21.32%
# epoch 10/100 - loss: 2.2859
# epoch 20/100 - loss: 2.2397
# epoch 30/100 - loss: 2.1871
# epoch 40/100 - loss: 2.1345
# epoch 50/100 - loss: 2.0838
# epoch 60/100 - loss: 2.0355
# epoch 70/100 - loss: 1.9897
# epoch 80/100 - loss: 1.9460
# epoch 90/100 - loss: 1.9044
# epoch 100/100 - loss: 1.8645
# classifier training done
# test accuracy: 18.71%
# Budget 10 - Accuracy: 18.71%
# epoch 10/100 - loss: 2.1080
# epoch 20/100 - loss: 1.7648
# epoch 30/100 - loss: 1.4695
# epoch 40/100 - loss: 1.2215
# epoch 50/100 - loss: 1.0158
# epoch 60/100 - loss: 0.8513
# epoch 70/100 - loss: 0.7211
# epoch 80/100 - loss: 0.6179
# epoch 90/100 - loss: 0.5358
# epoch 100/100 - loss: 0.4701
# classifier training done
# test accuracy: 36.61%
# Budget 10 - Accuracy: 36.61%
# epoch 10/100 - loss: 1.9444
# epoch 20/100 - loss: 1.4144
# epoch 30/100 - loss: 0.9877
# epoch 40/100 - loss: 0.6884
# epoch 50/100 - loss: 0.5008
# epoch 60/100 - loss: 0.3819
# epoch 70/100 - loss: 0.3051
# epoch 80/100 - loss: 0.2531
# epoch 90/100 - loss: 0.2160
# epoch 100/100 - loss: 0.1884
# classifier training done
# test accuracy: 36.94%
# Budget 10 - Accuracy: 36.94%
# epoch 10/100 - loss: 1.1105
# epoch 20/100 - loss: 0.2550
# epoch 30/100 - loss: 0.0880
# epoch 40/100 - loss: 0.0504
# epoch 50/100 - loss: 0.0370
# epoch 60/100 - loss: 0.0307
# epoch 70/100 - loss: 0.0269
# epoch 80/100 - loss: 0.0242
# epoch 90/100 - loss: 0.0221
# epoch 100/100 - loss: 0.0205
# classifier training done
# test accuracy: 37.27%
# Budget 10 - Accuracy: 37.27%
# epoch 10/100 - loss: 2.2598
# epoch 20/100 - loss: 2.1720
# epoch 30/100 - loss: 2.0794
# epoch 40/100 - loss: 1.9921
# epoch 50/100 - loss: 1.9113
# epoch 60/100 - loss: 1.8361
# epoch 70/100 - loss: 1.7658
# epoch 80/100 - loss: 1.6999
# epoch 90/100 - loss: 1.6380
# epoch 100/100 - loss: 1.5799
# classifier training done
# test accuracy: 37.42%
# Budget 50 - Accuracy: 37.42%
# epoch 10/100 - loss: 2.2813
# epoch 20/100 - loss: 2.2443
# epoch 30/100 - loss: 2.2026
# epoch 40/100 - loss: 2.1610
# epoch 50/100 - loss: 2.1210
# epoch 60/100 - loss: 2.0828
# epoch 70/100 - loss: 2.0463
# epoch 80/100 - loss: 2.0112
# epoch 90/100 - loss: 1.9775
# epoch 100/100 - loss: 1.9449
# classifier training done
# test accuracy: 33.79%
# Budget 50 - Accuracy: 33.79%
# epoch 10/100 - loss: 2.2924
# epoch 20/100 - loss: 2.2732
# epoch 30/100 - loss: 2.2510
# epoch 40/100 - loss: 2.2283
# epoch 50/100 - loss: 2.2060
# epoch 60/100 - loss: 2.1842
# epoch 70/100 - loss: 2.1631
# epoch 80/100 - loss: 2.1427
# epoch 90/100 - loss: 2.1228
# epoch 100/100 - loss: 2.1034
# classifier training done
# test accuracy: 29.70%
# Budget 50 - Accuracy: 29.70%
# epoch 10/100 - loss: 2.2128
# epoch 20/100 - loss: 2.0530
# epoch 30/100 - loss: 1.8966
# epoch 40/100 - loss: 1.7549
# epoch 50/100 - loss: 1.6274
# epoch 60/100 - loss: 1.5137
# epoch 70/100 - loss: 1.4128
# epoch 80/100 - loss: 1.3233
# epoch 90/100 - loss: 1.2438
# epoch 100/100 - loss: 1.1729
# classifier training done
# test accuracy: 40.91%
# Budget 50 - Accuracy: 40.91%
# epoch 10/100 - loss: 2.1418
# epoch 20/100 - loss: 1.8682
# epoch 30/100 - loss: 1.6162
# epoch 40/100 - loss: 1.4012
# epoch 50/100 - loss: 1.2279
# epoch 60/100 - loss: 1.0902
# epoch 70/100 - loss: 0.9797
# epoch 80/100 - loss: 0.8898
# epoch 90/100 - loss: 0.8155
# epoch 100/100 - loss: 0.7531
# classifier training done
# test accuracy: 43.23%
# Budget 50 - Accuracy: 43.23%
# epoch 10/100 - loss: 1.6926
# epoch 20/100 - loss: 0.9781
# epoch 30/100 - loss: 0.6164
# epoch 40/100 - loss: 0.4483
# epoch 50/100 - loss: 0.3562
# epoch 60/100 - loss: 0.2991
# epoch 70/100 - loss: 0.2594
# epoch 80/100 - loss: 0.2298
# epoch 90/100 - loss: 0.2066
# epoch 100/100 - loss: 0.1878
# classifier training done
# test accuracy: 44.41%
# Budget 50 - Accuracy: 44.41%
# epoch 10/100 - loss: 2.2770
# epoch 20/100 - loss: 2.2264
# epoch 30/100 - loss: 2.1687
# epoch 40/100 - loss: 2.1107
# epoch 50/100 - loss: 2.0544
# epoch 60/100 - loss: 2.0005
# epoch 70/100 - loss: 1.9492
# epoch 80/100 - loss: 1.9002
# epoch 90/100 - loss: 1.8537
# epoch 100/100 - loss: 1.8095
# classifier training done
# test accuracy: 42.54%
# Budget 100 - Accuracy: 42.54%
# epoch 10/100 - loss: 2.2987
# epoch 20/100 - loss: 2.2781
# epoch 30/100 - loss: 2.2540
# epoch 40/100 - loss: 2.2289
# epoch 50/100 - loss: 2.2040
# epoch 60/100 - loss: 2.1794
# epoch 70/100 - loss: 2.1552
# epoch 80/100 - loss: 2.1315
# epoch 90/100 - loss: 2.1083
# epoch 100/100 - loss: 2.0856
# classifier training done
# test accuracy: 38.11%
# Budget 100 - Accuracy: 38.11%
# epoch 10/100 - loss: 2.3035
# epoch 20/100 - loss: 2.2931
# epoch 30/100 - loss: 2.2808
# epoch 40/100 - loss: 2.2679
# epoch 50/100 - loss: 2.2550
# epoch 60/100 - loss: 2.2421
# epoch 70/100 - loss: 2.2293
# epoch 80/100 - loss: 2.2167
# epoch 90/100 - loss: 2.2042
# epoch 100/100 - loss: 2.1918
# classifier training done
# test accuracy: 36.29%
# Budget 100 - Accuracy: 36.29%
# epoch 10/100 - loss: 2.2606
# epoch 20/100 - loss: 2.1626
# epoch 30/100 - loss: 2.0548
# epoch 40/100 - loss: 1.9507
# epoch 50/100 - loss: 1.8542
# epoch 60/100 - loss: 1.7664
# epoch 70/100 - loss: 1.6871
# epoch 80/100 - loss: 1.6156
# epoch 90/100 - loss: 1.5512
# epoch 100/100 - loss: 1.4931
# classifier training done
# test accuracy: 44.80%
# Budget 100 - Accuracy: 44.80%
# epoch 10/100 - loss: 2.2132
# epoch 20/100 - loss: 2.0293
# epoch 30/100 - loss: 1.8412
# epoch 40/100 - loss: 1.6754
# epoch 50/100 - loss: 1.5377
# epoch 60/100 - loss: 1.4255
# epoch 70/100 - loss: 1.3340
# epoch 80/100 - loss: 1.2588
# epoch 90/100 - loss: 1.1962
# epoch 100/100 - loss: 1.1434
# classifier training done
# test accuracy: 46.74%
# Budget 100 - Accuracy: 46.74%
# epoch 10/100 - loss: 1.8933
# epoch 20/100 - loss: 1.3267
# epoch 30/100 - loss: 1.0256
# epoch 40/100 - loss: 0.8804
# epoch 50/100 - loss: 0.7973
# epoch 60/100 - loss: 0.7410
# epoch 70/100 - loss: 0.6983
# epoch 80/100 - loss: 0.6636
# epoch 90/100 - loss: 0.6340
# epoch 100/100 - loss: 0.6080
# classifier training done
# test accuracy: 47.61%
# Budget 100 - Accuracy: 47.61%
# epoch 10/100 - loss: 2.2751
# epoch 20/100 - loss: 2.2281
# epoch 30/100 - loss: 2.1769
# epoch 40/100 - loss: 2.1271
# epoch 50/100 - loss: 2.0797
# epoch 60/100 - loss: 2.0345
# epoch 70/100 - loss: 1.9915
# epoch 80/100 - loss: 1.9505
# epoch 90/100 - loss: 1.9113
# epoch 100/100 - loss: 1.8739
# classifier training done
# test accuracy: 42.90%
# Budget 200 - Accuracy: 42.90%
# epoch 10/100 - loss: 2.2923
# epoch 20/100 - loss: 2.2723
# epoch 30/100 - loss: 2.2495
# epoch 40/100 - loss: 2.2265
# epoch 50/100 - loss: 2.2041
# epoch 60/100 - loss: 2.1825
# epoch 70/100 - loss: 2.1616
# epoch 80/100 - loss: 2.1413
# epoch 90/100 - loss: 2.1216
# epoch 100/100 - loss: 2.1024
# classifier training done
# test accuracy: 35.72%
# Budget 200 - Accuracy: 35.72%
# epoch 10/100 - loss: 2.2944
# epoch 20/100 - loss: 2.2841
# epoch 30/100 - loss: 2.2721
# epoch 40/100 - loss: 2.2598
# epoch 50/100 - loss: 2.2476
# epoch 60/100 - loss: 2.2357
# epoch 70/100 - loss: 2.2241
# epoch 80/100 - loss: 2.2127
# epoch 90/100 - loss: 2.2015
# epoch 100/100 - loss: 2.1906
# classifier training done
# test accuracy: 32.87%
# Budget 200 - Accuracy: 32.87%
# epoch 10/100 - loss: 2.2572
# epoch 20/100 - loss: 2.1687
# epoch 30/100 - loss: 2.0772
# epoch 40/100 - loss: 1.9906
# epoch 50/100 - loss: 1.9101
# epoch 60/100 - loss: 1.8360
# epoch 70/100 - loss: 1.7683
# epoch 80/100 - loss: 1.7066
# epoch 90/100 - loss: 1.6504
# epoch 100/100 - loss: 1.5993
# classifier training done
# test accuracy: 45.66%
# Budget 200 - Accuracy: 45.66%
# epoch 10/100 - loss: 2.2147
# epoch 20/100 - loss: 2.0566
# epoch 30/100 - loss: 1.9001
# epoch 40/100 - loss: 1.7591
# epoch 50/100 - loss: 1.6392
# epoch 60/100 - loss: 1.5394
# epoch 70/100 - loss: 1.4566
# epoch 80/100 - loss: 1.3875
# epoch 90/100 - loss: 1.3293
# epoch 100/100 - loss: 1.2799
# classifier training done
# test accuracy: 47.42%
# Budget 200 - Accuracy: 47.42%
# epoch 10/100 - loss: 1.9446
# epoch 20/100 - loss: 1.4567
# epoch 30/100 - loss: 1.1757
# epoch 40/100 - loss: 1.0357
# epoch 50/100 - loss: 0.9571
# epoch 60/100 - loss: 0.9055
# epoch 70/100 - loss: 0.8676
# epoch 80/100 - loss: 0.8376
# epoch 90/100 - loss: 0.8126
# epoch 100/100 - loss: 0.7911
# classifier training done
# test accuracy: 48.72%
# Budget 200 - Accuracy: 48.72%
# epoch 10/100 - loss: 2.2858
# epoch 20/100 - loss: 2.2420
# epoch 30/100 - loss: 2.1955
# epoch 40/100 - loss: 2.1511
# epoch 50/100 - loss: 2.1093
# epoch 60/100 - loss: 2.0695
# epoch 70/100 - loss: 2.0315
# epoch 80/100 - loss: 1.9953
# epoch 90/100 - loss: 1.9606
# epoch 100/100 - loss: 1.9275
# classifier training done
# test accuracy: 38.64%
# Budget 300 - Accuracy: 38.64%
# epoch 10/100 - loss: 2.2957
# epoch 20/100 - loss: 2.2777
# epoch 30/100 - loss: 2.2572
# epoch 40/100 - loss: 2.2367
# epoch 50/100 - loss: 2.2168
# epoch 60/100 - loss: 2.1977
# epoch 70/100 - loss: 2.1793
# epoch 80/100 - loss: 2.1615
# epoch 90/100 - loss: 2.1442
# epoch 100/100 - loss: 2.1274
# classifier training done
# test accuracy: 24.39%
# Budget 300 - Accuracy: 24.39%
# epoch 10/100 - loss: 2.2994
# epoch 20/100 - loss: 2.2905
# epoch 30/100 - loss: 2.2800
# epoch 40/100 - loss: 2.2693
# epoch 50/100 - loss: 2.2587
# epoch 60/100 - loss: 2.2483
# epoch 70/100 - loss: 2.2382
# epoch 80/100 - loss: 2.2282
# epoch 90/100 - loss: 2.2185
# epoch 100/100 - loss: 2.2090
# classifier training done
# test accuracy: 11.40%
# Budget 300 - Accuracy: 11.40%
# epoch 10/100 - loss: 2.2589
# epoch 20/100 - loss: 2.1800
# epoch 30/100 - loss: 2.1004
# epoch 40/100 - loss: 2.0249
# epoch 50/100 - loss: 1.9541
# epoch 60/100 - loss: 1.8890
# epoch 70/100 - loss: 1.8295
# epoch 80/100 - loss: 1.7752
# epoch 90/100 - loss: 1.7257
# epoch 100/100 - loss: 1.6805
# classifier training done
# test accuracy: 42.24%
# Budget 300 - Accuracy: 42.24%
# epoch 10/100 - loss: 2.2221
# epoch 20/100 - loss: 2.0849
# epoch 30/100 - loss: 1.9477
# epoch 40/100 - loss: 1.8231
# epoch 50/100 - loss: 1.7175
# epoch 60/100 - loss: 1.6292
# epoch 70/100 - loss: 1.5556
# epoch 80/100 - loss: 1.4940
# epoch 90/100 - loss: 1.4419
# epoch 100/100 - loss: 1.3976
# classifier training done
# test accuracy: 46.12%
# Budget 300 - Accuracy: 46.12%
# epoch 10/100 - loss: 1.9871
# epoch 20/100 - loss: 1.5543
# epoch 30/100 - loss: 1.3045
# epoch 40/100 - loss: 1.1792
# epoch 50/100 - loss: 1.1092
# epoch 60/100 - loss: 1.0638
# epoch 70/100 - loss: 1.0309
# epoch 80/100 - loss: 1.0052
# epoch 90/100 - loss: 0.9841
# epoch 100/100 - loss: 0.9661
# classifier training done
# test accuracy: 49.67%
# Budget 300 - Accuracy: 49.67%
# epoch 10/100 - loss: 2.2848
# epoch 20/100 - loss: 2.2475
# epoch 30/100 - loss: 2.2058
# epoch 40/100 - loss: 2.1643
# epoch 50/100 - loss: 2.1243
# epoch 60/100 - loss: 2.0860
# epoch 70/100 - loss: 2.0493
# epoch 80/100 - loss: 2.0141
# epoch 90/100 - loss: 1.9805
# epoch 100/100 - loss: 1.9483
# classifier training done
# test accuracy: 42.58%
# Budget 400 - Accuracy: 42.58%
# epoch 10/100 - loss: 2.2960
# epoch 20/100 - loss: 2.2806
# epoch 30/100 - loss: 2.2628
# epoch 40/100 - loss: 2.2446
# epoch 50/100 - loss: 2.2267
# epoch 60/100 - loss: 2.2091
# epoch 70/100 - loss: 2.1919
# epoch 80/100 - loss: 2.1751
# epoch 90/100 - loss: 2.1587
# epoch 100/100 - loss: 2.1427
# classifier training done
# test accuracy: 35.42%
# Budget 400 - Accuracy: 35.42%
# epoch 10/100 - loss: 2.2997
# epoch 20/100 - loss: 2.2919
# epoch 30/100 - loss: 2.2828
# epoch 40/100 - loss: 2.2733
# epoch 50/100 - loss: 2.2638
# epoch 60/100 - loss: 2.2545
# epoch 70/100 - loss: 2.2452
# epoch 80/100 - loss: 2.2361
# epoch 90/100 - loss: 2.2272
# epoch 100/100 - loss: 2.2183
# classifier training done
# test accuracy: 31.29%
# Budget 400 - Accuracy: 31.29%
# epoch 10/100 - loss: 2.2710
# epoch 20/100 - loss: 2.1998
# epoch 30/100 - loss: 2.1234
# epoch 40/100 - loss: 2.0497
# epoch 50/100 - loss: 1.9806
# epoch 60/100 - loss: 1.9169
# epoch 70/100 - loss: 1.8584
# epoch 80/100 - loss: 1.8048
# epoch 90/100 - loss: 1.7559
# epoch 100/100 - loss: 1.7110
# classifier training done
# test accuracy: 44.04%
# Budget 400 - Accuracy: 44.04%
# epoch 10/100 - loss: 2.2303
# epoch 20/100 - loss: 2.1002
# epoch 30/100 - loss: 1.9668
# epoch 40/100 - loss: 1.8459
# epoch 50/100 - loss: 1.7424
# epoch 60/100 - loss: 1.6555
# epoch 70/100 - loss: 1.5827
# epoch 80/100 - loss: 1.5215
# epoch 90/100 - loss: 1.4697
# epoch 100/100 - loss: 1.4256
# classifier training done
# test accuracy: 46.52%
# Budget 400 - Accuracy: 46.52%
# epoch 10/100 - loss: 2.0113
# epoch 20/100 - loss: 1.5860
# epoch 30/100 - loss: 1.3346
# epoch 40/100 - loss: 1.2093
# epoch 50/100 - loss: 1.1418
# epoch 60/100 - loss: 1.0999
# epoch 70/100 - loss: 1.0703
# epoch 80/100 - loss: 1.0476
# epoch 90/100 - loss: 1.0291
# epoch 100/100 - loss: 1.0134
# classifier training done
# test accuracy: 50.31%
# Budget 400 - Accuracy: 50.31%
# epoch 10/100 - loss: 2.2899
# epoch 20/100 - loss: 2.2562
# epoch 30/100 - loss: 2.2186
# epoch 40/100 - loss: 2.1813
# epoch 50/100 - loss: 2.1454
# epoch 60/100 - loss: 2.1110
# epoch 70/100 - loss: 2.0780
# epoch 80/100 - loss: 2.0464
# epoch 90/100 - loss: 2.0160
# epoch 100/100 - loss: 1.9870
# classifier training done
# test accuracy: 43.35%
# Budget 500 - Accuracy: 43.35%
# epoch 10/100 - loss: 2.2993
# epoch 20/100 - loss: 2.2856
# epoch 30/100 - loss: 2.2697
# epoch 40/100 - loss: 2.2535
# epoch 50/100 - loss: 2.2374
# epoch 60/100 - loss: 2.2217
# epoch 70/100 - loss: 2.2063
# epoch 80/100 - loss: 2.1912
# epoch 90/100 - loss: 2.1764
# epoch 100/100 - loss: 2.1620
# classifier training done
# test accuracy: 40.57%
# Budget 500 - Accuracy: 40.57%
# epoch 10/100 - loss: 2.3013
# epoch 20/100 - loss: 2.2943
# epoch 30/100 - loss: 2.2860
# epoch 40/100 - loss: 2.2775
# epoch 50/100 - loss: 2.2689
# epoch 60/100 - loss: 2.2605
# epoch 70/100 - loss: 2.2522
# epoch 80/100 - loss: 2.2440
# epoch 90/100 - loss: 2.2359
# epoch 100/100 - loss: 2.2279
# classifier training done
# test accuracy: 35.95%
# Budget 500 - Accuracy: 35.95%
# epoch 10/100 - loss: 2.2731
# epoch 20/100 - loss: 2.2101
# epoch 30/100 - loss: 2.1417
# epoch 40/100 - loss: 2.0753
# epoch 50/100 - loss: 2.0129
# epoch 60/100 - loss: 1.9552
# epoch 70/100 - loss: 1.9021
# epoch 80/100 - loss: 1.8535
# epoch 90/100 - loss: 1.8088
# epoch 100/100 - loss: 1.7678
# classifier training done
# test accuracy: 46.78%
# Budget 500 - Accuracy: 46.78%
# epoch 10/100 - loss: 2.2401
# epoch 20/100 - loss: 2.1230
# epoch 30/100 - loss: 2.0027
# epoch 40/100 - loss: 1.8932
# epoch 50/100 - loss: 1.7989
# epoch 60/100 - loss: 1.7193
# epoch 70/100 - loss: 1.6522
# epoch 80/100 - loss: 1.5956
# epoch 90/100 - loss: 1.5476
# epoch 100/100 - loss: 1.5067
# classifier training done
# test accuracy: 48.84%
# Budget 500 - Accuracy: 48.84%
# epoch 10/100 - loss: 2.0451
# epoch 20/100 - loss: 1.6560
# epoch 30/100 - loss: 1.4228
# epoch 40/100 - loss: 1.3071
# epoch 50/100 - loss: 1.2462
# epoch 60/100 - loss: 1.2090
# epoch 70/100 - loss: 1.1832
# epoch 80/100 - loss: 1.1636
# epoch 90/100 - loss: 1.1478
# epoch 100/100 - loss: 1.1345
# classifier training done
# test accuracy: 50.68%
# Budget 500 - Accuracy: 50.68%
#
# Final Results:
# B=10, lr=0.025: 33.85%
# B=10, lr=0.01: 21.32%
# B=10, lr=0.005: 18.71%
# B=10, lr=0.05: 36.61%
# B=10, lr=0.1: 36.94%
# B=10, lr=0.5: 37.27%
# B=50, lr=0.025: 37.42%
# B=50, lr=0.01: 33.79%
# B=50, lr=0.005: 29.70%
# B=50, lr=0.05: 40.91%
# B=50, lr=0.1: 43.23%
# B=50, lr=0.5: 44.41%
# B=100, lr=0.025: 42.54%
# B=100, lr=0.01: 38.11%
# B=100, lr=0.005: 36.29%
# B=100, lr=0.05: 44.80%
# B=100, lr=0.1: 46.74%
# B=100, lr=0.5: 47.61%
# B=200, lr=0.025: 42.90%
# B=200, lr=0.01: 35.72%
# B=200, lr=0.005: 32.87%
# B=200, lr=0.05: 45.66%
# B=200, lr=0.1: 47.42%
# B=200, lr=0.5: 48.72%
# B=300, lr=0.025: 38.64%
# B=300, lr=0.01: 24.39%
# B=300, lr=0.005: 11.40%
# B=300, lr=0.05: 42.24%
# B=300, lr=0.1: 46.12%
# B=300, lr=0.5: 49.67%
# B=400, lr=0.025: 42.58%
# B=400, lr=0.01: 35.42%
# B=400, lr=0.005: 31.29%
# B=400, lr=0.05: 44.04%
# B=400, lr=0.1: 46.52%
# B=400, lr=0.5: 50.31%
# B=500, lr=0.025: 43.35%
# B=500, lr=0.01: 40.57%
# B=500, lr=0.005: 35.95%
# B=500, lr=0.05: 46.78%
# B=500, lr=0.1: 48.84%
# B=500, lr=0.5: 50.68%

# %% [markdown]
# Baseline

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
base_k = 20
base_lr = 0.025
results = {}

for B in budgets:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality(B, cluster, base_k)
    classifier = train_classifier(selected_indices, base_lr)
    accuracy = evaluate_classifier(classifier)
    results[B] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for B, acc in results.items():
    print(f"B={B}, {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 2.1847
# epoch 20/100 - loss: 1.9845
# epoch 30/100 - loss: 1.7906
# epoch 40/100 - loss: 1.6224
# epoch 50/100 - loss: 1.4752
# epoch 60/100 - loss: 1.3440
# epoch 70/100 - loss: 1.2263
# epoch 80/100 - loss: 1.1208
# epoch 90/100 - loss: 1.0265
# epoch 100/100 - loss: 0.9422
# classifier training done
# test accuracy: 33.00%
# Budget 10 - Accuracy: 33.00%
# epoch 10/100 - loss: 2.2677
# epoch 20/100 - loss: 2.1840
# epoch 30/100 - loss: 2.0965
# epoch 40/100 - loss: 2.0147
# epoch 50/100 - loss: 1.9393
# epoch 60/100 - loss: 1.8692
# epoch 70/100 - loss: 1.8037
# epoch 80/100 - loss: 1.7422
# epoch 90/100 - loss: 1.6844
# epoch 100/100 - loss: 1.6300
# classifier training done
# test accuracy: 33.12%
# Budget 50 - Accuracy: 33.12%
# epoch 10/100 - loss: 2.2770
# epoch 20/100 - loss: 2.2178
# epoch 30/100 - loss: 2.1537
# epoch 40/100 - loss: 2.0917
# epoch 50/100 - loss: 2.0330
# epoch 60/100 - loss: 1.9775
# epoch 70/100 - loss: 1.9248
# epoch 80/100 - loss: 1.8748
# epoch 90/100 - loss: 1.8273
# epoch 100/100 - loss: 1.7822
# classifier training done
# test accuracy: 35.87%
# Budget 100 - Accuracy: 35.87%
# epoch 10/100 - loss: 2.2830
# epoch 20/100 - loss: 2.2364
# epoch 30/100 - loss: 2.1858
# epoch 40/100 - loss: 2.1368
# epoch 50/100 - loss: 2.0902
# epoch 60/100 - loss: 2.0458
# epoch 70/100 - loss: 2.0034
# epoch 80/100 - loss: 1.9629
# epoch 90/100 - loss: 1.9242
# epoch 100/100 - loss: 1.8873
# classifier training done
# test accuracy: 37.27%
# Budget 200 - Accuracy: 37.27%
# epoch 10/100 - loss: 2.2802
# epoch 20/100 - loss: 2.2356
# epoch 30/100 - loss: 2.1873
# epoch 40/100 - loss: 2.1407
# epoch 50/100 - loss: 2.0965
# epoch 60/100 - loss: 2.0545
# epoch 70/100 - loss: 2.0145
# epoch 80/100 - loss: 1.9763
# epoch 90/100 - loss: 1.9398
# epoch 100/100 - loss: 1.9049
# classifier training done
# test accuracy: 39.23%
# Budget 300 - Accuracy: 39.23%
# epoch 10/100 - loss: 2.2810
# epoch 20/100 - loss: 2.2435
# epoch 30/100 - loss: 2.2019
# epoch 40/100 - loss: 2.1609
# epoch 50/100 - loss: 2.1216
# epoch 60/100 - loss: 2.0841
# epoch 70/100 - loss: 2.0484
# epoch 80/100 - loss: 2.0142
# epoch 90/100 - loss: 1.9816
# epoch 100/100 - loss: 1.9505
# classifier training done
# test accuracy: 39.87%
# Budget 400 - Accuracy: 39.87%
# epoch 10/100 - loss: 2.2865
# epoch 20/100 - loss: 2.2511
# epoch 30/100 - loss: 2.2115
# epoch 40/100 - loss: 2.1723
# epoch 50/100 - loss: 2.1345
# epoch 60/100 - loss: 2.0982
# epoch 70/100 - loss: 2.0635
# epoch 80/100 - loss: 2.0301
# epoch 90/100 - loss: 1.9982
# epoch 100/100 - loss: 1.9676
# classifier training done
# test accuracy: 44.62%
# Budget 500 - Accuracy: 44.62%
#
# Final Results:
# B=10, 33.00%
# B=50, 33.12%
# B=100, 35.87%
# B=200, 37.27%
# B=300, 39.23%
# B=400, 39.87%
# B=500, 44.62%

# %% [markdown]
# Final Test

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
best_k = 60
best_lr = 0.5
results = {}

for B in budgets:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality(B, cluster, best_k)
    classifier = train_classifier(selected_indices, best_lr)
    accuracy = evaluate_classifier(classifier)
    results[B] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for B, acc in results.items():
    print(f"B={B}, {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 1.1057
# epoch 20/100 - loss: 0.2554
# epoch 30/100 - loss: 0.0884
# epoch 40/100 - loss: 0.0506
# epoch 50/100 - loss: 0.0372
# epoch 60/100 - loss: 0.0308
# epoch 70/100 - loss: 0.0269
# epoch 80/100 - loss: 0.0243
# epoch 90/100 - loss: 0.0222
# epoch 100/100 - loss: 0.0205
# classifier training done
# test accuracy: 37.16%
# Budget 10 - Accuracy: 37.16%
# epoch 10/100 - loss: 1.6947
# epoch 20/100 - loss: 0.9776
# epoch 30/100 - loss: 0.6157
# epoch 40/100 - loss: 0.4478
# epoch 50/100 - loss: 0.3558
# epoch 60/100 - loss: 0.2989
# epoch 70/100 - loss: 0.2592
# epoch 80/100 - loss: 0.2296
# epoch 90/100 - loss: 0.2064
# epoch 100/100 - loss: 0.1876
# classifier training done
# test accuracy: 44.33%
# Budget 50 - Accuracy: 44.33%
# epoch 10/100 - loss: 1.8933
# epoch 20/100 - loss: 1.3272
# epoch 30/100 - loss: 1.0259
# epoch 40/100 - loss: 0.8805
# epoch 50/100 - loss: 0.7974
# epoch 60/100 - loss: 0.7411
# epoch 70/100 - loss: 0.6984
# epoch 80/100 - loss: 0.6637
# epoch 90/100 - loss: 0.6341
# epoch 100/100 - loss: 0.6081
# classifier training done
# test accuracy: 47.53%
# Budget 100 - Accuracy: 47.53%
# epoch 10/100 - loss: 1.9460
# epoch 20/100 - loss: 1.4564
# epoch 30/100 - loss: 1.1749
# epoch 40/100 - loss: 1.0349
# epoch 50/100 - loss: 0.9564
# epoch 60/100 - loss: 0.9048
# epoch 70/100 - loss: 0.8669
# epoch 80/100 - loss: 0.8369
# epoch 90/100 - loss: 0.8119
# epoch 100/100 - loss: 0.7904
# classifier training done
# test accuracy: 48.66%
# Budget 200 - Accuracy: 48.66%
# epoch 10/100 - loss: 1.9918
# epoch 20/100 - loss: 1.5561
# epoch 30/100 - loss: 1.3047
# epoch 40/100 - loss: 1.1790
# epoch 50/100 - loss: 1.1089
# epoch 60/100 - loss: 1.0635
# epoch 70/100 - loss: 1.0307
# epoch 80/100 - loss: 1.0050
# epoch 90/100 - loss: 0.9839
# epoch 100/100 - loss: 0.9659
# classifier training done
# test accuracy: 49.76%
# Budget 300 - Accuracy: 49.76%
# epoch 10/100 - loss: 2.0092
# epoch 20/100 - loss: 1.5844
# epoch 30/100 - loss: 1.3335
# epoch 40/100 - loss: 1.2086
# epoch 50/100 - loss: 1.1413
# epoch 60/100 - loss: 1.0995
# epoch 70/100 - loss: 1.0701
# epoch 80/100 - loss: 1.0475
# epoch 90/100 - loss: 1.0290
# epoch 100/100 - loss: 1.0133
# classifier training done
# test accuracy: 50.36%
# Budget 400 - Accuracy: 50.36%
# epoch 10/100 - loss: 2.0408
# epoch 20/100 - loss: 1.6541
# epoch 30/100 - loss: 1.4221
# epoch 40/100 - loss: 1.3068
# epoch 50/100 - loss: 1.2459
# epoch 60/100 - loss: 1.2088
# epoch 70/100 - loss: 1.1830
# epoch 80/100 - loss: 1.1634
# epoch 90/100 - loss: 1.1476
# epoch 100/100 - loss: 1.1342
# classifier training done
# test accuracy: 50.61%
# Budget 500 - Accuracy: 50.61%
#
# Final Results:
# B=10, 37.16%
# B=50, 44.33%
# B=100, 47.53%
# B=200, 48.66%
# B=300, 49.76%
# B=400, 50.36%
# B=500, 50.61%

# %% [markdown]
# # Modification

# %%
def get_highest_typicality_cosine(K, clusters, k):
  selected_indices = []
  for clustid in range(K): # goes through all 10 clusters one by one
    # print("ID",clustid)
    cluster_idx = np.where(clusters == clustid)[0] # checks if each point is in that cluster
    if len(cluster_idx) < 5:
      continue

    embeddings_for_cluster = embeddings[cluster_idx] # embedding of this cluster

    k_neighbours = min(k, len(cluster_idx)) # only distance to k embeddings - we don't calculate typicality for all
    neighbours = NearestNeighbors(n_neighbors=k_neighbours, metric='cosine').fit(embeddings_for_cluster)
    nbdist,_ = neighbours.kneighbors(embeddings_for_cluster)

    avg_dist = nbdist[:, 1:].mean(axis=1)
    typicality = 1 / (avg_dist + 1e-8) # avoids division by 0

    highest_typicality_local = np.argmax(typicality)
    highest_typicality_global = cluster_idx[highest_typicality_local]

    selected_indices.append(highest_typicality_global)

  selected_indices = np.array(selected_indices)
  # print("selected indices: ", selected_indices)
  return selected_indices

# %% [markdown]
# Optimized Baseline

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
base_k = 20
base_lr = 0.025
results = {}

for B in budgets:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality_cosine(B, cluster, base_k)
    classifier = train_classifier(selected_indices, base_lr)
    accuracy = evaluate_classifier(classifier)
    results[B] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for B, acc in results.items():
    print(f"B={B}, {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 2.1929
# epoch 20/100 - loss: 1.9929
# epoch 30/100 - loss: 1.7988
# epoch 40/100 - loss: 1.6299
# epoch 50/100 - loss: 1.4821
# epoch 60/100 - loss: 1.3502
# epoch 70/100 - loss: 1.2319
# epoch 80/100 - loss: 1.1258
# epoch 90/100 - loss: 1.0309
# epoch 100/100 - loss: 0.9461
# classifier training done
# test accuracy: 33.17%
# Budget 10 - Accuracy: 33.17%
# epoch 10/100 - loss: 2.2652
# epoch 20/100 - loss: 2.1857
# epoch 30/100 - loss: 2.1007
# epoch 40/100 - loss: 2.0195
# epoch 50/100 - loss: 1.9436
# epoch 60/100 - loss: 1.8724
# epoch 70/100 - loss: 1.8055
# epoch 80/100 - loss: 1.7426
# epoch 90/100 - loss: 1.6832
# epoch 100/100 - loss: 1.6272
# classifier training done
# test accuracy: 35.41%
# Budget 50 - Accuracy: 35.41%
# epoch 10/100 - loss: 2.2803
# epoch 20/100 - loss: 2.2256
# epoch 30/100 - loss: 2.1648
# epoch 40/100 - loss: 2.1048
# epoch 50/100 - loss: 2.0472
# epoch 60/100 - loss: 1.9924
# epoch 70/100 - loss: 1.9402
# epoch 80/100 - loss: 1.8905
# epoch 90/100 - loss: 1.8432
# epoch 100/100 - loss: 1.7982
# classifier training done
# test accuracy: 38.15%
# Budget 100 - Accuracy: 38.15%
# epoch 10/100 - loss: 2.2795
# epoch 20/100 - loss: 2.2340
# epoch 30/100 - loss: 2.1842
# epoch 40/100 - loss: 2.1357
# epoch 50/100 - loss: 2.0894
# epoch 60/100 - loss: 2.0453
# epoch 70/100 - loss: 2.0032
# epoch 80/100 - loss: 1.9631
# epoch 90/100 - loss: 1.9247
# epoch 100/100 - loss: 1.8882
# classifier training done
# test accuracy: 38.47%
# Budget 200 - Accuracy: 38.47%
# epoch 10/100 - loss: 2.2785
# epoch 20/100 - loss: 2.2358
# epoch 30/100 - loss: 2.1895
# epoch 40/100 - loss: 2.1448
# epoch 50/100 - loss: 2.1023
# epoch 60/100 - loss: 2.0619
# epoch 70/100 - loss: 2.0234
# epoch 80/100 - loss: 1.9867
# epoch 90/100 - loss: 1.9516
# epoch 100/100 - loss: 1.9181
# classifier training done
# test accuracy: 39.51%
# Budget 300 - Accuracy: 39.51%
# epoch 10/100 - loss: 2.2911
# epoch 20/100 - loss: 2.2534
# epoch 30/100 - loss: 2.2116
# epoch 40/100 - loss: 2.1704
# epoch 50/100 - loss: 2.1310
# epoch 60/100 - loss: 2.0933
# epoch 70/100 - loss: 2.0573
# epoch 80/100 - loss: 2.0229
# epoch 90/100 - loss: 1.9901
# epoch 100/100 - loss: 1.9587
# classifier training done
# test accuracy: 41.95%
# Budget 400 - Accuracy: 41.95%
# epoch 10/100 - loss: 2.2921
# epoch 20/100 - loss: 2.2573
# epoch 30/100 - loss: 2.2181
# epoch 40/100 - loss: 2.1790
# epoch 50/100 - loss: 2.1411
# epoch 60/100 - loss: 2.1047
# epoch 70/100 - loss: 2.0698
# epoch 80/100 - loss: 2.0363
# epoch 90/100 - loss: 2.0042
# epoch 100/100 - loss: 1.9735
# classifier training done
# test accuracy: 45.05%
# Budget 500 - Accuracy: 45.05%
#
# Final Results:
# B=10, 33.17%
# B=50, 35.41%
# B=100, 38.15%
# B=200, 38.47%
# B=300, 39.51%
# B=400, 41.95%
# B=500, 45.05%

# %% [markdown]
# Final Test

# %%
budgets = [10, 50, 100, 200, 300, 400, 500]
best_k = 60
best_lr = 0.5
results = {}

for B in budgets:
    K, cluster = cluster_embeddings(B)
    selected_indices = get_highest_typicality_cosine(B, cluster, best_k)
    classifier = train_classifier(selected_indices, best_lr)
    accuracy = evaluate_classifier(classifier)
    results[B] = accuracy
    print(f"Budget {B} - Accuracy: {accuracy:.2f}%")


print("\nFinal Results:")
for B, acc in results.items():
    print(f"B={B}, {acc:.2f}%")
# Out:
# epoch 10/100 - loss: 1.0976
# epoch 20/100 - loss: 0.2521
# epoch 30/100 - loss: 0.0877
# epoch 40/100 - loss: 0.0502
# epoch 50/100 - loss: 0.0369
# epoch 60/100 - loss: 0.0306
# epoch 70/100 - loss: 0.0268
# epoch 80/100 - loss: 0.0241
# epoch 90/100 - loss: 0.0220
# epoch 100/100 - loss: 0.0204
# classifier training done
# test accuracy: 37.34%
# Budget 10 - Accuracy: 37.34%
# epoch 10/100 - loss: 1.6938
# epoch 20/100 - loss: 0.9835
# epoch 30/100 - loss: 0.6242
# epoch 40/100 - loss: 0.4564
# epoch 50/100 - loss: 0.3636
# epoch 60/100 - loss: 0.3059
# epoch 70/100 - loss: 0.2655
# epoch 80/100 - loss: 0.2352
# epoch 90/100 - loss: 0.2114
# epoch 100/100 - loss: 0.1920
# classifier training done
# test accuracy: 43.90%
# Budget 50 - Accuracy: 43.90%
# epoch 10/100 - loss: 1.8829
# epoch 20/100 - loss: 1.3124
# epoch 30/100 - loss: 1.0120
# epoch 40/100 - loss: 0.8675
# epoch 50/100 - loss: 0.7849
# epoch 60/100 - loss: 0.7289
# epoch 70/100 - loss: 0.6863
# epoch 80/100 - loss: 0.6516
# epoch 90/100 - loss: 0.6219
# epoch 100/100 - loss: 0.5959
# classifier training done
# test accuracy: 47.56%
# Budget 100 - Accuracy: 47.56%
# epoch 10/100 - loss: 1.9505
# epoch 20/100 - loss: 1.4626
# epoch 30/100 - loss: 1.1810
# epoch 40/100 - loss: 1.0411
# epoch 50/100 - loss: 0.9621
# epoch 60/100 - loss: 0.9101
# epoch 70/100 - loss: 0.8716
# epoch 80/100 - loss: 0.8411
# epoch 90/100 - loss: 0.8156
# epoch 100/100 - loss: 0.7936
# classifier training done
# test accuracy: 48.27%
# Budget 200 - Accuracy: 48.27%
# epoch 10/100 - loss: 1.9977
# epoch 20/100 - loss: 1.5701
# epoch 30/100 - loss: 1.3242
# epoch 40/100 - loss: 1.2012
# epoch 50/100 - loss: 1.1330
# epoch 60/100 - loss: 1.0893
# epoch 70/100 - loss: 1.0580
# epoch 80/100 - loss: 1.0339
# epoch 90/100 - loss: 1.0142
# epoch 100/100 - loss: 0.9974
# classifier training done
# test accuracy: 49.47%
# Budget 300 - Accuracy: 49.47%
# epoch 10/100 - loss: 2.0123
# epoch 20/100 - loss: 1.5945
# epoch 30/100 - loss: 1.3475
# epoch 40/100 - loss: 1.2245
# epoch 50/100 - loss: 1.1583
# epoch 60/100 - loss: 1.1172
# epoch 70/100 - loss: 1.0883
# epoch 80/100 - loss: 1.0661
# epoch 90/100 - loss: 1.0479
# epoch 100/100 - loss: 1.0324
# classifier training done
# test accuracy: 49.63%
# Budget 400 - Accuracy: 49.63%
# epoch 10/100 - loss: 2.0409
# epoch 20/100 - loss: 1.6567
# epoch 30/100 - loss: 1.4262
# epoch 40/100 - loss: 1.3117
# epoch 50/100 - loss: 1.2514
# epoch 60/100 - loss: 1.2148
# epoch 70/100 - loss: 1.1896
# epoch 80/100 - loss: 1.1704
# epoch 90/100 - loss: 1.1550
# epoch 100/100 - loss: 1.1421
# classifier training done
# test accuracy: 50.54%
# Budget 500 - Accuracy: 50.54%
#
# Final Results:
# B=10, 37.34%
# B=50, 43.90%
# B=100, 47.56%
# B=200, 48.27%
# B=300, 49.47%
# B=400, 49.63%
# B=500, 50.54%
